# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
ecc = np.random.beta(0.867,3.03, size=100000)
ax = sns.distplot(ecc, kde=False)
ax.set(xlabel='eccentricity', title=r'$\beta(0.867,3.03)$')
plt.show()
